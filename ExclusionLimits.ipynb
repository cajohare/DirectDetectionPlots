# %% [markdown]
# # Exclusion lmits

# %%
from numpy import *
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from PlotFuncs import *

plt.style.use('sty.mplstyle')

fig, ax = plt.subplots()

dirc = 'data/limits/Nucleon/SI/'

rot_45 = 18

PlotBound(ax,dirc+'LZ_2024.txt',edgecolor='darkgreen',textcolor='darkgreen',facecolor=[0.0, 0.62, 0.38],label='LZ',rotation=rot_45,label_pos=[1000,1e-47])
PlotBound(ax,dirc+'XENONnT_non-power-constrained.txt',edgecolor='teal',textcolor='teal',facealpha=0,label='XENONnT',rotation=rot_45,label_pos=[1000,7e-46])
PlotBound(ax,dirc+'XENONnT_non-power-constrained.txt',edgecolor='teal',facecolor='teal',facealpha=0.5,zorder=-3)
PlotBound(ax,dirc+'PandaX_2024.txt',edgecolor='navy',textcolor='navy',facealpha=0,label='PandaX',rotation=rot_45,label_pos=[1000,0.8e-46])
PlotBound(ax,dirc+'PandaX_2024.txt',edgecolor='navy',facecolor='navy',facealpha=0.5,zorder=-2)
PlotBound(ax,dirc+'CRESST.txt',edgecolor=[0.8, 0.25, 0.33],textcolor=[0.8, 0.25, 0.33],facecolor=[0.74, 0.56, 0.56],zorder=-1,label='CRESST',rotation=-40,label_pos=[1,0.8e-38])
PlotBound(ax,dirc+'DarkSide.txt',edgecolor='seagreen',textcolor='seagreen',facecolor='seagreen',facealpha=0.0,label='DarkSide',rotation=0,label_pos=[5,0.8e-42])
PlotBound(ax,dirc+'DarkSide.txt',edgecolor='seagreen',textcolor='seagreen',facecolor='seagreen',facealpha=0.5,zorder=-3)
PlotBound(ax,dirc+'EDELWEISS.txt',edgecolor='orange',textcolor='orange',facealpha=0,label='EDELWEISS',rotation=rot_45,label_pos=[20,0.8e-43])
PlotBound(ax,dirc+'DEAP-3600.txt',edgecolor='#4ff09d',textcolor='#4ff09d',facealpha=0,label='DEAP-3600',rotation=rot_45,label_pos=[300,0.8e-44])
PlotBound(ax,dirc+'PICO60.txt',edgecolor=[0.5, 0.0, 0.13],textcolor=[0.5, 0.0, 0.13],facealpha=0,label='PICO60',rotation=rot_45,label_pos=[300,6e-44])
PlotBound(ax,dirc+'COSINE-100.txt',edgecolor='gold',textcolor='gold',facealpha=0,label='COSINE-100',rotation=rot_45,label_pos=[300,6e-42])
PlotBound(ax,dirc+'LUX.txt',edgecolor='crimson',textcolor='crimson',facealpha=0,label='LUX',rotation=rot_45,label_pos=[300,1e-45])
PlotBound(ax,dirc+'NEWS-G.txt',edgecolor='m',textcolor='m',facealpha=0,label='NEWS-G',rotation=-20,label_pos=[1,1e-38])
PlotBound(ax,dirc+'XENON1T-Migdal.txt',edgecolor='teal',textcolor='teal',linestyle=':',facealpha=0,label='XENON1T (Migdal)',fontsize=15,rotation=-20,label_pos=[0.5,0.3e-38],path_effects=None)
PlotBound(ax,dirc+'DAMA1.txt',y2=nan,edgecolor='darkslategray',textcolor='darkslategray',facecolor='forestgreen',label='DAMA',label_pos=[20,7e-41])
PlotBound(ax,dirc+'DAMA2.txt',y2=nan,edgecolor='darkslategray',textcolor='darkslategray',facecolor='forestgreen')
PlotBound(ax,'data/fog/Nucleon/SI/nuFog_n2_Xe.txt',y2=0,label=r'\begin{center} Neutrino fog \linebreak (Xe)\end{center}',label_pos=[0.7,2e-46],rotation=0,facecolor='#a7b9d6',lw=0)
#PlotBound(ax,dirc+'LXe_1000tonyear_3sigma.txt',linestyle='--',facealpha=0)



PlotBound(ax, 'data/models/Nucleon/SI/NMSSM_Scan.txt',y2=nan,lw=1,path_effects=None,textcolor='gray',edgecolor='dimgray',facecolor='gray',facealpha=0.5,label=r'\begin{center} {\bf NMSSM}\end{center}',rotation=17,label_pos=[170,1.5e-48],text_path_effects=None,hatch='/')



ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlim([0.1,1e4])
ax.set_ylim([5e-50,1e-37])
ax.set_xlabel('Dark matter mass [GeV]')
ax.set_ylabel(r'SI nucleon cross section [cm$^{2}$]')

locmaj = matplotlib.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
locmin = matplotlib.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
ax.yaxis.set_major_locator(locmaj)
ax.yaxis.set_minor_locator(locmin)

MySaveFig(fig,'Nucleon_SI')

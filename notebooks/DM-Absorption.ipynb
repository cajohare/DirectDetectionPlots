# %% [markdown]
# # DM-absorption

# %% [markdown]
# # Dark photon

# %%
from numpy import *
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from PlotFuncs import *

plt.style.use('sty.mplstyle')

fig,ax = plt.subplots()

fpath = '../data/limits/Electron/DarkPhoton/'

# high mass DM
PlotBound(ax,fpath+'XENON_2024_Combined.txt',label=r'\begin{center}{\bf XENONnT \linebreak (DM)}\end{center}',label_pos=[0.5e3,2.1e-17],edgecolor='teal',facealpha=0,textcolor='teal',rotation=0,zorder=2,fontsize=20,start_x=20,end_x=-1)
PlotBound(ax,fpath+'XENON_2024_Combined.txt',facecolor=col_alpha('teal',0.5),zorder=-10,lw=0)
PlotBound(ax,fpath+'DarkSide.txt',label=r'{\bf DarkSide}',label_pos=[0.5e2,0.8e-16],edgecolor='seagreen',facealpha=0,textcolor='seagreen',rotation=0,zorder=2,fontsize=20,start_x=1,end_x=-1)
PlotBound(ax,fpath+'DarkSide.txt',facecolor=col_alpha('seagreen',0.5),zorder=-1,lw=0)
PlotBound(ax,fpath+'SuperCDMS.txt',label=r'{\bf SuperCDMS}',label_pos=[0.2e6,0.4e-9],edgecolor='gold',facealpha=0,textcolor='gold',rotation=43,zorder=2,fontsize=20,start_x=1,end_x=-1)
PlotBound(ax,fpath+'EDELWEISS.txt',label=r'{\bf EDELWEISS}',label_pos=[4.6e5,1.2e-10],edgecolor='orange',facealpha=0,textcolor='orange',rotation=43,zorder=2,fontsize=20,start_x=1,end_x=-1)
PlotBound(ax,fpath+'GERDA.txt',label=r'{\bf GERDA}',label_pos=[1.4e6,5.2e-11],edgecolor='violet',facealpha=0,textcolor='violet',rotation=43,zorder=2,fontsize=20,start_x=1,end_x=-1)
PlotBound(ax,fpath+'PandaX.txt',label=r'{\bf PandaX}',label_pos=[0.6e6,2.5e-12],edgecolor='navy',facealpha=0,textcolor='navy',rotation=43,zorder=2,fontsize=20,start_x=1,end_x=-1)
PlotBound(ax,fpath+'PandaX.txt',facecolor=col_alpha('navy',0.5),zorder=-120,lw=0)


# CCD
PlotBound(ax,fpath+'SENSEI_2024_Combined.txt',label=r'{\bf SENSEI}',label_pos=[1.2e1,1.0e-13],edgecolor='#993186',facealpha=0,textcolor='#993186',rotation=0,zorder=2,fontsize=20,start_x=1,end_x=-1)
PlotBound(ax,fpath+'SENSEI_2024_Combined.txt',facecolor=col_alpha('#993186',0.5),zorder=0,lw=0)
PlotBound(ax,fpath+'DAMIC.txt',label=r'{\bf DAMIC}',label_pos=[0.7e1,5.0e-13],edgecolor='#6e0b3c',facealpha=0,textcolor='#6e0b3c',rotation=0,zorder=2,fontsize=20,start_x=1,end_x=-1)
PlotBound(ax,fpath+'DAMIC.txt',facecolor=col_alpha('#6e0b3c',0.5),zorder=0,lw=0)

# eV/THz
PlotBound(ax,fpath+'FUNK.txt',label=r'{\bf FUNK}',label_pos=[0.85e1,4e-10],edgecolor='crimson',facecolor=col_alpha('crimson',0.6),textcolor='crimson',rotation=-90,zorder=2,fontsize=21,path_effects=line_background(4,'k'))
PlotBound(ax,fpath+'Tokyo-Dish.txt',label=r'{\bf Tokyo}',label_pos=[0.28e1,3e-10],edgecolor='maroon',facecolor=col_alpha('maroon',0.6),textcolor='maroon',rotation=-90,zorder=2,fontsize=20,path_effects=line_background(4,'k'))
PlotBound(ax,fpath+'LAMPOST.txt',label=r'{\bf LAMPOST}',label_pos=[0.6e0,3e-10],edgecolor='red',facecolor=col_alpha('red',0.6),textcolor='red',rotation=90,zorder=2,fontsize=20,path_effects=line_background(4,'k'))
PlotBound(ax,fpath+'MuDHI.txt',label=r'{\bf MuDHI}',label_pos=[1.1e1,1.7e-8],edgecolor='darkred',facecolor=col_alpha('darkred',0.6),textcolor='darkred',rotation=0,zorder=2,fontsize=20,path_effects=line_background(4,'k'))
SimpleAnnotation(ax,1e1,0.28e1,2e-8,1e-8,color='darkred')


# Stellar/astrophysical bounds
PlotBound(ax,fpath+'XENON1T_Solar_SE.txt',label=r'\begin{center}{\bf XENON1T \linebreak (Solar)}\end{center}',label_pos=[0.24,4.7e-13],edgecolor='teal',textcolor='teal',facealpha=1,facecolor=col_alpha('gray',0.5),rotation=-31.5,zorder=0,fontsize=20)
PlotBound(ax,fpath+'GlobularClusters.txt',label=r'{\bf GC}',label_pos=[4e3,4.0e-15],edgecolor='gray',facealpha=1,facecolor=col_alpha('gray',0.5),textcolor='gray',text_path_effects=None,rotation=0,zorder=0,fontsize=23,path_effects=None,lw=2)
PlotBound(ax,fpath+'Solar.txt',label=r'{\bf Sun}',label_pos=[0.6e3,5.0e-13],edgecolor='gray',facealpha=1,facecolor=col_alpha('gray',0.5),textcolor='gray',text_path_effects=None,rotation=0,zorder=0,fontsize=23,path_effects=None,lw=2)
PlotBound(ax,fpath+'Solar-Global.txt',rescale_m=True,edgecolor='gray',facealpha=1,facecolor=col_alpha('gray',0.5),zorder=0,path_effects=None,lw=2)
PlotBound(ax,fpath+'CAST.txt',label=r'{\bf CAST}',label_pos=[20,2.8e-12],edgecolor='gray',facealpha=1,facecolor=col_alpha('gray',0.5),textcolor='gray',text_path_effects=None,rotation=-16,zorder=0,fontsize=22,path_effects=None,lw=2)
PlotBound(ax,fpath+'SolarBasin.txt',label=r'{\bf Basin}',label_pos=[2.8e4,3e-12],edgecolor='gray',facealpha=1,facecolor=col_alpha('gray',0.5),textcolor='gray',text_path_effects=None,rotation=80,zorder=-0.01,fontsize=17,path_effects=None,lw=2)

# Indirect DM detection
PlotBound(ax,fpath+'Cosmology_Arias.txt',label=r'{\bf Diffuse X-ray}',label_pos=[5e4,0.35e-10],edgecolor='gray',facealpha=1,textcolor='gray',facecolor=col_alpha('gray',0.2),text_path_effects=None,rotation=90,zorder=-0.001,fontsize=20,path_effects=None,lw=2)
PlotBound(ax,fpath+'INTEGRAL.txt',label=r'\begin{center}{\bf INTEGRAL \linebreak (DM)}\end{center}',label_pos=[0.25e6,4e-14],edgecolor='gray',facealpha=1,textcolor='gray',facecolor=col_alpha('gray',0.2),text_path_effects=None,rotation=-67,zorder=0,fontsize=20,path_effects=None,lw=2)
PlotBound(ax,fpath+'JWST.txt',label=r'\begin{center}{\bf JWST \linebreak (DM)}\end{center}',label_pos=[6e-2,0.6e-9],edgecolor='gray',facealpha=1,facecolor=col_alpha('gray',0.2),textcolor='gray',text_path_effects=None,rotation=0,zorder=0,fontsize=20,path_effects=None,lw=2)



# Inflationary defect-free bound production https://arxiv.org/pdf/2310.18397
ax.annotate("", xytext=(1.5e5, 6e-16),xy=(2.4e5, 2e-16),arrowprops=dict(facecolor='gray'),zorder=-200)
m = array([1e-2,1e7])
chi = 1.14e-18*(m/1e3)**(5/4)
plt.plot(m,chi,'-',lw=3,color='gray',path_effects=line_background(4,'k'),zorder=-20)
plt.text(0.3e4,0.25e-17,r'\begin{center}Minimal inflationary \linebreak production\end{center}',color='k',rotation=37.5,fontsize=18)

# Decay to e+e-
me = 511e3
mchi = geomspace(2*me,1e10,1000)
tU =  (13.8e9*3600*24*365.25)/6.5821e-16 # eV^-1
gmax = sqrt((137*3/(tU*mchi))*(1-4*me**2/mchi**2)**(-1/2)*(1+2*me**2/mchi**2)**-1)
plt.fill_between(mchi,gmax,y2=1,lw=0,color=col_alpha('gray',0.2),zorder=-10)



# Finishing touches
#plt.fill_between([1e6,1e7],[1e-20,1e-20],y2=1,lw=0,color=col_alpha('gray',0.2),zorder=-10)
plt.plot([2*511e3,2*511e3],[1e-19,1e0],'--',lw=2,color='gray',zorder=-10)
plt.text(2.3*511e3,0.3e-17,'$2 m_e$',fontsize=20,color='gray')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlim([0.01,1e7])
ax.set_ylim([1e-18,1e-7])
ax.set_xlabel('Dark photon mass [eV]')
ax.set_ylabel(r'Kinetic mixing, $\varepsilon$',labelpad=10)
locmaj = matplotlib.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
locmin = matplotlib.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
ax.yaxis.set_major_locator(locmaj)
ax.yaxis.set_minor_locator(locmin)
locmaj = matplotlib.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
locmin = matplotlib.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
ax.xaxis.set_major_locator(locmaj)
ax.xaxis.set_minor_locator(locmin)


MySaveFig(fig,'DarkPhoton')

# Add Projections
PlotBound(ax,fpath+'Projections/IAXO-Longitudinal.txt',label=r'{\bf IAXO}',label_pos=[2e-2,4e-13],path_effects=None,edgecolor='gray',facealpha=0,linestyle='--',textcolor='gray',lw=3,zorder=-10,fontsize=22,text_path_effects=None)
PlotBound(ax,fpath+'Projections/LAMPOST.txt',label=r'{\bf LAMPOST}',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2,label_pos=[0.3,0.7e-16],path_effects=None,edgecolor='gray',facealpha=0,linestyle='--',textcolor='gray',lw=3,text_path_effects=None,rotation=19,zorder=-10,fontsize=20)
PlotBound(ax,fpath+'Projections/OSCURA.txt',label=r'{\bf Oscura}',label_pos=[5.5,0.18e-16],path_effects=None,edgecolor='gray',facealpha=0,linestyle='--',textcolor='gray',lw=3,text_path_effects=None,rotation=0,zorder=-10,fontsize=20)

MySaveFig(fig,'DarkPhoton_with_Projections')
# Out:
# /var/folders/c5/ms4qz_795ll784bwyy3sqj3m0000gn/T/ipykernel_22288/3480131073.py:65: RuntimeWarning: divide by zero encountered in power
#   gmax = sqrt((137*3/(tU*mchi))*(1-4*me**2/mchi**2)**(-1/2)*(1+2*me**2/mchi**2)**-1)

# %% [markdown]
# # Axion-electron coupling

# %%
from numpy import *
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from PlotFuncs import *

plt.style.use('sty.mplstyle')

fig,ax = plt.subplots()

fpath = '../data/limits/Electron/Axion/'

# high mass DM
PlotBound(ax,fpath+'XENON_2024_Combined.txt',label=r'\begin{center}{\bf XENONnT \linebreak (DM)}\end{center}',label_pos=[0.5e3,3.1e-15],edgecolor='teal',facealpha=0,textcolor='teal',rotation=0,zorder=2,fontsize=20,start_x=1,end_x=-1)
PlotBound(ax,fpath+'XENON_2024_Combined.txt',facecolor=col_alpha('teal',0.5),zorder=-20,lw=0)
PlotBound(ax,fpath+'DarkSide.txt',label=r'{\bf DarkSide}',label_pos=[0.15e2,2.1e-13],edgecolor='seagreen',facealpha=0,textcolor='seagreen',rotation=0,zorder=2,fontsize=20,start_x=1,end_x=-1)
PlotBound(ax,fpath+'DarkSide.txt',facecolor=col_alpha('seagreen',0.5),zorder=-1,lw=0)
PlotBound(ax,fpath+'SuperCDMS.txt',label=r'{\bf SuperCDMS}',label_pos=[0.06e6,0.3e-10],edgecolor='gold',facealpha=0,textcolor='gold',rotation=43,zorder=2,fontsize=20,start_x=1,end_x=-1)
PlotBound(ax,fpath+'EDELWEISS.txt',label=r'{\bf EDELWEISS}',label_pos=[2.6e5,0.9e-10],edgecolor='orange',facealpha=0,textcolor='orange',rotation=0,zorder=2,fontsize=18,start_x=1,end_x=-1)
PlotBound(ax,fpath+'GERDA.txt',label=r'{\bf GERDA}',label_pos=[1.1e6,1.2e-11],edgecolor='violet',facealpha=0,textcolor='violet',rotation=0,zorder=2,fontsize=20,start_x=1,end_x=-1)
PlotBound(ax,fpath+'PandaX.txt',label=r'{\bf PandaX}',label_pos=[0.18e6,0.5e-12],edgecolor='navy',facealpha=0,textcolor='navy',rotation=0,zorder=2,fontsize=22,start_x=1,end_x=-1)
PlotBound(ax,fpath+'PandaX.txt',facecolor=col_alpha('navy',0.5),zorder=-120,lw=0)
#PlotBound(ax,fpath+'AllLimits-2024.txt',facecolor=col_alpha('navy',0.5),zorder=100)


# Stellar/astrophysical bounds
PlotBound(ax,fpath+'SolarBasin.txt',label=r'\begin{center}{\bf Solar basin}\end{center}',label_pos=[0.5e3,0.8e-11],edgecolor='gray',facealpha=1,textcolor='gray',facecolor=col_alpha('gray',0.5),text_path_effects=None,rotation=0,zorder=1,fontsize=23,path_effects=None,lw=2)
PlotBound(ax,fpath+'SolarNu.txt',label=r'{\bf Sun}',label_pos=[1.7e-1,4.0e-11],edgecolor='gray',facealpha=1,facecolor=col_alpha('gray',0.5),textcolor='gray',text_path_effects=None,rotation=0,zorder=1,fontsize=24,path_effects=None,lw=2)
PlotBound(ax,fpath+'RedGiants_HighMass.txt',label=r'{\bf Red Giants ($\omega$Cen)}',label_pos=[1.2e-1,1.8e-13],edgecolor='gray',facealpha=1,facecolor=col_alpha('gray',0.5),textcolor='gray',text_path_effects=None,rotation=0,zorder=0,fontsize=23,path_effects=None,lw=2)
PlotBound(ax,fpath+'IrreducibleFreezeIn.txt',y2=nan,label=r'{\bf Freeze-in}',label_pos=[1.4e5,3e-14],edgecolor='gray',facealpha=1,textcolor='gray',facecolor=col_alpha('gray',0.5),text_path_effects=None,rotation=-55,zorder=-0.1,fontsize=23,path_effects=None,lw=2)
PlotBound(ax,fpath+'IrreducibleFreezeIn_ee.txt',y2=nan,edgecolor='gray',facealpha=1,textcolor='gray',facecolor=col_alpha('gray',0.5),zorder=-0.1,lw=2,path_effects=None)
PlotBound(ax,fpath+'SN1987A.txt',y2=nan,label=r'{\bf SN1987A}',label_pos=[3e5,3e-9],edgecolor='gray',facealpha=1,textcolor='gray',facecolor=col_alpha('gray',0.5),text_path_effects=None,rotation=0,zorder=-0.1,fontsize=23,path_effects=None,lw=2)

# Indirect DM bound
PlotBound(ax,fpath+'Xray_1loop.txt',label=r'\begin{center}{\bf X-rays \linebreak (DM)}\end{center}',label_pos=[1e5,2e-16],edgecolor='gray',facealpha=1,textcolor='gray',facecolor=col_alpha('gray',0.2),text_path_effects=None,rotation=-55,zorder=-10,fontsize=20,path_effects=None,lw=2)

# Decay to e+e-
# me = 511e3
# ma = geomspace(2*me,1e7,1000)
# tU =  (13.8e9*3600*24*365.25)/6.5821e-16 # eV^-1
# gmax = sqrt((1/tU)*(8*pi/ma)/sqrt(1-4*me**2/ma**2))
# plt.plot(ma,gmax,'r-',zorder=100)


# QCD axions
def g_x(C_ae,m_a):
    return 8.943e-11*C_ae*m_a
DFSZ_u = 1.0/3.0
DFSZ_l = 2.0e-5
KSVZ = 2e-4
Had_u = 5e-3
Had_l = 1.5e-4
m = array([1e-20,1e10])
plt.fill_between(m,g_x(DFSZ_u,m),y2=g_x(DFSZ_l,m),color='orange',lw=0,alpha=0.2,zorder=-100)
plt.plot(m,g_x(DFSZ_l,m),'--',color='orange',lw=2,zorder=-100)
plt.fill_between(m,g_x(Had_u,m),y2=g_x(Had_l,m),color='orange',lw=0,alpha=0.2,zorder=-100)
plt.plot(m,g_x(Had_l,m),'--',color='orange',lw=2,zorder=-100)
plt.plot(m,g_x(Had_u,m),'--',color='orange',lw=2,zorder=-100)
plt.text(0.12e0,9.5e-15,r'{\bf QCD axion}',color='orange',rotation=31,fontsize=20)
plt.text(0.5e0,1.3e-15,'DFSZ',color='orange',rotation=31,fontsize=16)
plt.text(0.22e0,4.0e-15,'KSVZ-like',color='orange',rotation=31,fontsize=16)

# Finishing touches
plt.fill_between([1e6,1e7],[1e-20,1e-20],y2=1,lw=0,color=col_alpha('gray',0.2),zorder=-10)
plt.plot([2*511e3,2*511e3],[1e-19,1e0],'--',lw=2,color='gray',zorder=-10)
plt.text(2.3*511e3,0.3e-17,'$2 m_e$',fontsize=20,color='gray')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlim([0.1,1e7])
ax.set_ylim([1e-18,1e-8])
ax.set_xlabel('Axion mass, $m_a$ [eV]')
ax.set_ylabel(r'Axion-electron coupling, $g_{ae}$',labelpad=10)
locmaj = matplotlib.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
locmin = matplotlib.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
ax.yaxis.set_major_locator(locmaj)
ax.yaxis.set_minor_locator(locmin)
locmaj = matplotlib.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
locmin = matplotlib.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
ax.xaxis.set_major_locator(locmaj)
ax.xaxis.set_minor_locator(locmin)


MySaveFig(fig,'AxionElectron')

# MySaveFig(fig,'AxionElectron_with_Projections')

# %%
fpath = '../data/limits/Electron/DarkPhoton/'
file_list = ['Xenon1T_S1S2','XENON1T_SE','Xenon100','XENONnT']
CreateEnvelope(fpath,file_list,'XENON_2024_Combined',1e1,209199.2736761691,nm=1000,header='Combination of all XENON/XENON1T/XENONnT/ Dark photon dark matter limits  \n Mass [eV] \t kinetic mixing')

fpath = '../data/limits/Electron/DarkPhoton/'
file_list = ['SENSEI','SENSEI_1e']
CreateEnvelope(fpath,file_list,'SENSEI_2024_Combined',1.2242564395119855,19.534018000353004,nm=1000,header='Combination of SENSEI and SENSEI_1e \n Mass [eV] \t kinetic mixing')

fpath = '../data/limits/Electron/DarkPhoton/'
file_list = ['SENSEI_2024_Combined','INTEGRAL','XENON_2024_Combined','DarkSide','XENON1T_Solar_SE']
CreateEnvelope(fpath,file_list,'AllLimits-2024',1e-2,1e7,nm=1000,header='All limits as of 2024 \n Mass [eV] \t kinetic mixing')

# %%
fpath = '../data/limits/Electron/Axion/'
file_list = ['XENONnT','XENON1T_DM_S1S2','XENON1T_DM_S2','XENON1T_DM_SE']
CreateEnvelope(fpath,file_list,'XENON_2024_Combined',11.316311117770704,140794.19061696145,nm=1000,header='Combination of all XENON/XENON1T/XENONnT/ Axion-electron dark matter limits  \n Mass [eV] \t g_ae')


fpath = '../data/limits/Electron/Axion/'
file_list = ['XENON_2024_Combined','DarkSide','Xray_1loop','RedGiants_HighMass']
CreateEnvelope(fpath,file_list,'AllLimits-2024',1e-2,1e6,nm=1000,header='All limits as of 2024 \n Mass [eV] \t g_ae')

# %%
H0 = 1/(14e9*3600*24*365.25)
G = 6.67e-11
R = 1.5e11
rho_c = 3*H0**2/(8*pi*G)
rho_c*(4/3*pi*R**3)
# Out:
# 129614605.41106744

# %% [markdown]
# # Exclusion lmits

# %%
from numpy import *
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from PlotFuncs import *

plt.style.use('sty.mplstyle')

fig, ax = plt.subplots()

dirc = '../data/limits/Nucleon/SI/'

rot_45 = 18

# Plot limits
PlotBound(ax,dirc+'LZ_2024.txt',edgecolor='darkgreen',textcolor='darkgreen',facecolor=[0.0, 0.62, 0.38],label=r'{\bf LZ}',rotation=rot_45,label_pos=[2000,1.8e-47])
PlotBound(ax,dirc+'XENONnT_2024_Combined.txt',edgecolor='teal',textcolor='teal',facealpha=0,label=r'{\bf XENONnT}',rotation=rot_45,label_pos=[1000,8.0e-46])
PlotBound(ax,dirc+'XENONnT_2024_Combined.txt',edgecolor='teal',textcolor='teal',facecolor=col_alpha('teal',0.5),zorder=-1)
PlotBound(ax,dirc+'XENON1T-Migdal.txt',edgecolor='teal',textcolor='teal',linestyle=':',facealpha=0,label='XENON1T (Migdal)',fontsize=15,rotation=-38,label_pos=[0.5,0.3e-38],path_effects=None)
PlotBound(ax,dirc+'PandaX_2024_Combined.txt',edgecolor='navy',textcolor='navy',facealpha=0,label=r'{\bf PandaX}',rotation=rot_45,label_pos=[1500,1.0e-46])
PlotBound(ax,dirc+'PandaX_2024_Combined.txt',edgecolor='navy',textcolor='navy',facecolor=col_alpha('navy',0.5),zorder=-1.1)
PlotBound(ax,dirc+'CRESST.txt',edgecolor=[0.8, 0.25, 0.33],textcolor=[0.8, 0.25, 0.33],facecolor=[0.74, 0.56, 0.56],zorder=-1,label=r'{\bf CRESST}',rotation=-41,label_pos=[0.9,1.5e-38],fontsize=22)
PlotBound(ax,dirc+'DarkSide.txt',edgecolor='seagreen',textcolor='seagreen',facecolor='seagreen',facealpha=0.0,label=r'{\bf DarkSide}',rotation=-26,label_pos=[0.9,1e-41],fontsize=22)
PlotBound(ax,dirc+'DarkSide.txt',edgecolor='seagreen',textcolor='seagreen',facecolor='seagreen',facealpha=0.5,zorder=-3)
PlotBound(ax,dirc+'EDELWEISS.txt',edgecolor='orange',textcolor='orange',facealpha=0,label=r'{\bf EDELWEISS}',rotation=-45,label_pos=[8,3e-42],fontsize=17)
PlotBound(ax,dirc+'DEAP-3600.txt',edgecolor='#4ff09d',textcolor='#4ff09d',facealpha=0,label=r'{\bf DEAP-3600}',rotation=rot_45-1,label_pos=[1000,1.9e-44])
PlotBound(ax,dirc+'PICO60.txt',edgecolor=[0.5, 0.0, 0.13],textcolor=[0.5, 0.0, 0.13],facealpha=0,label=r'{\bf PICO60}',rotation=rot_45-8,label_pos=[40,1e-43])
PlotBound(ax,dirc+'COSINE-100.txt',edgecolor='gold',textcolor='gold',facealpha=0,label=r'{\bf COSINE-100}',rotation=rot_45-2,label_pos=[300,7e-42])
#PlotBound(ax,dirc+'LUX.txt',edgecolor='crimson',textcolor='crimson',facealpha=0,label='LUX',rotation=rot_45,label_pos=[300,1e-45])
PlotBound(ax,dirc+'NEWS-G.txt',edgecolor='m',textcolor='m',facealpha=0,label=r'{\bf NEWS-G}',rotation=6,label_pos=[17,0.35e-38])


# neutrino fog
PlotBound(ax,'../data/fog/Nucleon/SI/nuFog_n2_Xe.txt',y2=0,label=r'\begin{center} {\bf Neutrino fog \linebreak (Xe)}\end{center}',label_pos=[0.3,7e-47],fontsize=29,rotation=0,facecolor='#a7b9d6',lw=0,textcolor='#a7b9d6',facealpha=0.5)


# DAMA
PlotBound(ax,dirc+'DAMA1.txt',y2=nan,edgecolor='darkslategray',textcolor='darkslategray',facecolor='forestgreen',label=r'{\bf DAMA}',label_pos=[22,5e-40])
PlotBound(ax,dirc+'DAMA2.txt',y2=nan,edgecolor='darkslategray',textcolor='darkslategray',facecolor='forestgreen')
plt.arrow(0.485, 0.735, -0.012, -0.018, transform=fig.transFigure,figure=fig,length_includes_head=False,lw=1,head_width=0.007, head_length=0.014, overhang=0.13,edgecolor='darkslategray',facecolor='darkslategray',clip_on=True,path_effects=line_background(2,'k'))
plt.arrow(0.55, 0.73, 0.012, -0.055, transform=fig.transFigure,figure=fig,length_includes_head=False,lw=1,head_width=0.007, head_length=0.014, overhang=0.13,edgecolor='darkslategray',facecolor='darkslategray',clip_on=True,path_effects=line_background(2,'k'))


# Models
PlotBound(ax, '../data/models/Nucleon/SI/NMSSM_Scan.txt',y2=nan,lw=1,path_effects=None,textcolor='gray',edgecolor='dimgray',facecolor='gray',facealpha=0.5,label=r'\begin{center} {\bf NMSSM}\end{center}',rotation=17,label_pos=[190,1.5e-48],text_path_effects=None,hatch='/')


# Finishing touches
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlim([0.1,1e4])
ax.set_ylim([5e-50,1e-37])
ax.set_xlabel('Dark matter mass [GeV/$c^2$]')
ax.set_ylabel(r'SI DM-nucleon cross section [cm$^{2}$]')
locmaj = matplotlib.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
locmin = matplotlib.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
ax.yaxis.set_major_locator(locmaj)
ax.yaxis.set_minor_locator(locmin)



MySaveFig(fig,'Nucleon_SI')
